# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np

# %%
# %run ".\\funciones_auxiliares\\graficar_vectores.ipynb"

# %%
a = np.array([[-1,3],[2,-2]])
a
# Out:
# array([[-1,  3],
#        [ 2, -2]])

# %%
vector = np.array([2,1])
vector
# Out:
# array([2, 1])

# %%
#Flaten vuelve los matrices como un vector estirado
vector.flatten()
# Out:
# array([2, 1])

# %%
a.flatten()
# Out:
# array([-1,  3,  2, -2])

# %%
graficar_vectores([vector.flatten()], cols='blue')
plt.xlim(-0.5, 3 )
plt.ylim(-0.5, 2 )
# Out:
# (-0.5, 2)

# %%
vector_transformado = a.dot(vector)
vector_transformado
# Out:
# array([1, 2])

# %%
graficar_vectores([vector.flatten(), vector_transformado.flatten()], cols=['blue','red'])
plt.xlim(-0.5, 3 )
plt.ylim(-0.5, 3 )
# Out:
# (-0.5, 3)

# %%
np.linalg.norm(vector)
# Out:
# 2.23606797749979

# %%
np.linalg.norm(vector_transformado)
# Out:
# 2.23606797749979
