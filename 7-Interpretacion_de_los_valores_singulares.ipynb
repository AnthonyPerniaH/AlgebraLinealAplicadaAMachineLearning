# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np 
# %run ".\\funciones_auxiliares\\graficar_vectores.ipynb"
# %run ".\\funciones_auxiliares\\graficar_matriz.ipynb"

# %%
a = np.array([[3,7],[5,2]])
a
# Out:
# array([[3, 7],
#        [5, 2]])

# %%
u , d , v = np.linalg.svd(a)
print(d[0])
print(d[1])
# Out:
# 8.7133796929634
# 3.3282148858288965

# %%
u1 = [d[0]*u[0,0],d[0]*u[0,1]]
u1
# Out:
# [-7.412043479297569, -4.580894796297923]

# %%
v1 = [d[1]*u[1,0], d[1],u[1,1]]
v1
# Out:
# [-1.7497461132982814, 3.3282148858288965, 0.85065080835204]

# %%
print([a[0,0], a[1,0]])
print(u1)
print()
print([a[0,1], a[1,1]])
print(v1)
# Out:
# [3, 5]
# [-7.412043479297569, -4.580894796297923]
#
# [7, 2]
# [-1.7497461132982814, 3.3282148858288965, 0.85065080835204]

# %%
graficarMatriz(a)
graficar_vectores([u1,v1], cols=['red','blue'])

plt.text(3,5,r"$u_1$", size = 18)
plt.text(7,2,r"$v_1$", size = 18)

plt.text(-5,-4,r"$D(u_1)$", size = 18)
plt.text(-4,1,r"$D(v_1)$", size = 18)

plt.xlim(-8,8)
plt.ylim(-8,8)
# Out:
# (-8, 8)
